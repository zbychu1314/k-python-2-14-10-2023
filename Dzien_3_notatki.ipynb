# %% [markdown]
# Obsługa błędów
# try
# except
# finally
# możemy czase pominąć except, try jest zawsze plus na pewno except lub finally

# %% [markdown]
# może być również wiele except po try, obslugujemy rozne rodzaje bledow

# %% [markdown]
# logging.error(f'Wystapli blad: {e}')
# mozemy logowac tylko okreslone zdarzenia np error warning, critical, debug
# logi mozna zapisywac do pliku albo do systemu obslugujacego logi

# %% [markdown]
# Nie wykorzystywac obslugi blędów do sterowania logiką np lapie wyjatek i zwracam -1

# %% [markdown]
# ---------- 06 wyrażenia warunkowe ---------------------------

# %% [markdown]
# podstawy match-case
# umozliwia porownywanie calych struktur

# %% [markdown]
# Wyrazenia regularne
# 1111-111-111
# \d{4}-\d{3}-\d{3}
# \w - litera lub cyfra
# michal@op.pl -- > \w+@\w+\.\w{2,3}
#
# ![image.png](attachment:4610bf53-9938-4d99-b28e-ed1a9270774f.png)

# %% [markdown]
# ![image.png](attachment:4881d11e-b3b0-483b-903e-daccd997c5b0.png)

# %%
pojazdy = [
    {"typ": "samochód", "marka": "Toyota", "model": "Corolla", "rok_produkcji": 2005},
    {"typ": "motocykl", "marka": "Yamaha", "model": "YZF-R3"},
    {"typ": "samochód", "marka": "Tesla", "model": "Model X", "rok_produkcji": 2020},
    {"typ": "rower"},
    {"marka": "Kawasaki"},
]
for pojazd in pojazdy:
    match pojazd:
        wynik = {}
        case {'typ':n} if n=='samochód'
            wynik['typ']='Samochód'
        case {'typ':n} if n=='rower'
            wynik['typ']='Rower'
        case {'typ':n} if n==''
            wynik['typ']=''
        case {'marka':m} if m=='Toyota'
            wynik['marka']='Toyota'
        case {'marka':m} if m=='Toyota'
            wynik['marka']='Toyota'
# Out:
#   Cell In[5], line 9
#     match pojazd:
#           ^
# SyntaxError: invalid syntax
