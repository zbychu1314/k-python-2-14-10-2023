# %%
# %%latex
# \tableofcontents
# Out:
# \tableofcontents

# %% [markdown]
# # Podstawy
#
# Język obiektowy, wspierający różne paradygmaty programowania. O szerokich zastosowaniach. Interpretowany. Z dużą społecznością. Bardzo popularny.
#
# Python to popularny język programowania wysokiego poziomu, który po raz pierwszy został wydany w 1991 roku przez Guido van Rossuma, holenderskiego programistę komputerowego. Oto krótka historia Pythona:
#
# Van Rossum rozpoczął pracę nad Pythonem w grudniu 1989 roku, kiedy pracował w Narodowym Instytucie Badawczym Matematyki i Informatyki w Holandii. Zainspirował go szereg innych języków programowania, w tym ABC, Modula-3 i C.
#
# Python został oficjalnie wydany 20 lutego 1991 roku. Jego nazwa została zainspirowana brytyjską grupą komediową Monty Python.
#
# Na początku lat 90. Python był używany głównie do zadań związanych z administrowaniem systemem oraz jako język skryptowy dla większych projektów programistycznych.
#
# Pod koniec lat 90. Python zyskał popularność jako język programowania ogólnego przeznaczenia i zaczął być używany w wielu zastosowaniach, w tym w obliczeniach naukowych, analizie danych i tworzeniu stron internetowych.
#
# W 2000 roku wydano Python 2.0, który wprowadził szereg nowych funkcji, w tym obsługę Unicode i system wyrzucania elementów bezużytecznych.
#
# W 2008 roku wydano Python 3.0, który wprowadził istotne zmiany w składni języka i standardowej bibliotece. Python 3.0 nie był wstecznie kompatybilny z wcześniejszymi wersjami Pythona, co spowodowało pewne zamieszanie wśród użytkowników i spowolniło jego wdrażanie.
#
# Obecnie Python jest jednym z najpopularniejszych języków programowania na świecie i jest używany w wielu dziedzinach, w tym w tworzeniu stron internetowych, nauce o danych, uczeniu maszynowym i obliczeniach naukowych.
#
# **UWAGA**
#
# Ten kurs zakłada, że znasz już podstawowe koncepcje związane z Pythonem. Znasz kilka wbudowanych typów. Umiesz posługiwać się podstawowymi konstrukcjami. Umiesz definiowac proste funkcje i klasy.
# Ten materiał tę wiedzę pogłębia i uzupełnia.

# %% [markdown]
# ## Interpreter
#
# Interpreter Pythona to program, który jest odpowiedzialny za wykonywanie kodu napisanego w języku Python. Gdy chcesz uruchomić kod Pythona, musisz go zapisać w pliku z rozszerzeniem ".py" i następnie uruchomić interpreter Pythona za pomocą polecenia "python" w wierszu poleceń.
#
# Interpreter Pythona działa w następujący sposób:
#
# * Wczytuje plik z kodem Pythona i przechodzi przez go linia po linii, analizując go i tworząc odpowiedni model danych w pamięci i kompiluje go do bytecode, który jest zoptymalizowany pod kątem wydajności.
#
# * Gdy interpreter napotka instrukcję, wykonuje ją. Może to być np. instrukcja przypisania wartości do zmiennej, wywołanie funkcji lub instrukcja warunkowa (np. if).
#
# * Jeśli interpreter napotka błąd podczas analizy lub wykonywania kodu, wyświetli komunikat o błędzie i zatrzyma wykonywanie kodu.
#
# * Gdy interpreter dojdzie do końca kodu, zakończy działanie.
#
# Ponieważ bytecode jest zoptymalizowany pod kątem wydajności, interpreter Pythona jest w stanie szybciej wykonywać kod niż interpreter innych języków programowania, które nie wykorzystują kompilacji do bytecode.
#
# Interpreter Pythona umożliwia wykonywanie kodu w trybie interaktywnym, co pozwala na testowanie i debugowanie kodu linijka po linijce. Możesz to zrobić, uruchamiając interpreter Pythona bez podawania nazwy pliku, np. poprzez wpisanie polecenia "python" w wierszu poleceń.
#
# #### Dodatkowe parametry przy uruchamianiu skryptów:
#
# Przy uruchamianiu skryptów Pythona możesz używać różnych dodatkowych parametrów, które pozwalają na zmianę sposobu działania interpretera lub skryptu. Oto kilka przykładów takich parametrów:
#
# *    `-d`: Służy do włączenia opcji debugowania. Dzięki temu interpreter wyświetli dodatkowe informacje, takie jak nazwy zmiennych i wartości, które mogą pomóc w debugowaniu kodu.
#
# *    `-O`: Służy do włączenia optymalizacji kodu. Dzięki temu interpreter zoptymalizuje bytecode, co może przyspieszyć wykonywanie kodu.
#
# *    `-i`: Służy do uruchomienia skryptu w trybie interaktywnym po jego zakończeniu. Po wykonaniu skryptu interpreter pozostanie aktywny, co pozwala na testowanie i debugowanie kodu linijka po linijce.
#
# *    `-m` module: Służy do uruchomienia modułu Pythona jako skrypt. Pozwala to na uruchamianie modułów bez konieczności importowania ich do innych skryptów.
#
# *    `-c` command: Służy do wykonania polecenia Pythona z linii poleceń. Pozwala to na wykonywanie pojedynczych poleceń bez konieczności tworzenia osobnego pliku skryptu.
#
#
#
#
#     $ python nazwa.py
#
#     $ python
#
#     $ python -i nazwa.py

# %% [markdown]
#   ## Pierwsza pomoc
#
# ### Pomoc pythona - `help`
#
# W Pythonie, system pomocy jest potężnym narzędziem, które umożliwia programistom szybkie uzyskanie informacji o dostępnych modułach, klasach, funkcjach czy metodach. Dzięki wbudowanej funkcji `help()`, użytkownik może z łatwością przeglądać dokumentację bez opuszczania interaktywnego środowiska Pythona.
#
#
# Aby skorzystać z funkcji `help()`, wystarczy przekazać do niej nazwę interesującego nas obiektu, klasy, metody czy funkcji:
#
# ```python
# help(str)
# ```
#
# Wynik pokaże dokumentację dla wbudowanego typu `str`, czyli napisów w Pythonie.

# %%
# help()
help(str.upper)
# Out:
# Help on method_descriptor:
#
# upper(self, /)
#     Return a copy of the string converted to uppercase.

# %%
str.upper("ala")
# Out:
# 'ALA'

# %%
"ala".upper()
# Out:
# 'ALA'

# %%
help("ala".upper())
# Out:
# No Python documentation found for 'ALA'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %% [markdown]
# #### Pomoc dla konkretnych metod
#
# Jeśli chcesz dowiedzieć się więcej o konkretnej metodzie klasy, możesz ją podać bezpośrednio:
#
# ```python
# help(str.upper)
# ```
#
# Zobaczysz informacje na temat metody `upper()` klasy `str`.
#
# #### Pomoc w interaktywnym środowisku
#
# Jeśli korzystasz z interaktywnego środowiska takiego jak IPython, czy Jypyter, często możesz użyć znaku zapytania (`?`) przed lub po nazwie obiektu, aby uzyskać szybką pomoc:
#
# ```python
# str.upper?
# ```
#
# W środowisku IPython podwójny znak zapytania (`??`) służy do wyświetlenia źródła funkcji lub metody (o ile jest dostępne). To może być szczególnie przydatne, jeśli chcesz zrozumieć, jak coś działa "pod spodem" lub jeśli potrzebujesz dokładniejszych informacji niż te dostarczane przez standardową pomoc.
#
# ##### Przykład
#
# Załóżmy, że masz zdefiniowaną następującą funkcję:
#
# ```python
# def przykladowa_funkcja():
#     """To jest przykładowa funkcja."""
#     print("Witaj w przykładowej funkcji!")
# ```

# %%
def przykladowa_funkcja():
    """To jest przykładowa funkcja."""
    print("Witaj w przykładowej funkcji!")

# %%
przykladowa_funkcja.__name__ = "cos"

# %%
help(przykladowa_funkcja)
# Out:
# Help on function cos in module __main__:
#
# cos()
#     To jest przykładowa funkcja.

# %%
przykladowa_funkcja()
# Out:
# Witaj w przykładowej funkcji!

# %%
przykladowa_funkcja.__name__
# Out:
# 'cos'

# %%
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
przykladowa_funkcja??
# Out:
# Signature: przykladowa_funkcja()
# Source:
# def przykladowa_funkcja():
#     """To jest przykładowa funkcja."""
#     print("Witaj w przykładowej funkcji!")
# File:      c:\users\kurs\appdata\local\temp\ipykernel_720\1184017068.py
# Type:      function

# %% [markdown]
# W IPython możesz użyć podwójnego znaku zapytania, aby zobaczyć jej kod źródłowy:
#
# ```
# przykladowa_funkcja??
# ```
#
# W wyniku zostanie wyświetlony kod źródłowy funkcji:
#
# ```python
# def przykladowa_funkcja():
#     """To jest przykładowa funkcja."""
#     print("Witaj w przykładowej funkcji!")
# ```
#
# To narzędzie staje się jeszcze bardziej wartościowe, gdy pracujesz z bibliotekami zewnętrznymi lub chcesz zrozumieć, jak działają wbudowane funkcje i metody Pythona (choć w przypadku niektórych wbudowanych funkcji kod źródłowy może nie być dostępny).
#
# Warto zauważyć, że `??` może nie zawsze pokazywać kod źródłowy, jeśli np. funkcja jest napisana w języku innym niż Python (np. w C dla pewnych funkcji wbudowanych) albo gdy kod jest ukryty (np. dla funkcji z pakietów komercyjnych czy zaszyfrowanych).
#
# #### Przeglądanie dostępnych modułów
#
# Aby przeglądać dostępne moduły w bieżącym środowisku, użyj `help("modules")`.
#
# #### Wyszukiwanie w dokumentacji
#
# Jeśli nie jesteś pewien, czego dokładnie szukasz, możesz również wyszukać pewnych terminów:
#
# ```python
# help("keywords")
# ```
#
# #### Przykład
#
# Rozważmy prosty przykład z wbudowaną funkcją `print`:
#
# ```python
# help(print)
# ```
#
# W wyniku otrzymasz pełną dokumentację funkcji `print`, wraz z informacjami o jej argumentach, sposobie użycia i tym, co robi.
#
# #### Podsumowanie
#
# Funkcja `help()` w Pythonie to nieocenione narzędzie dla każdego programisty, zarówno początkującego, jak i doświadczonego. Umożliwia szybki dostęp do dokumentacji, pomagając w zrozumieniu i wykorzystaniu różnych funkcji, klas i modułów dostępnych w języku.

# %% [markdown]
# ### Funkcja `dir()`

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_13',
#  '_14',
#  '_15',
#  '_20',
#  '_5',
#  '_7',
#  '_8',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'open',
#  'przykladowa_funkcja',
#  'quit']

# %% [markdown]
# #### Czym jest funkcja `dir()`?
#
# Funkcja `dir()` jest wbudowaną funkcją w Pythonie, która zwraca listę atrybutów i metod dla danego obiektu. Jeśli nie podasz żadnego argumentu, `dir()` zwróci listę nazw w bieżącym zakresie lokalnym.
#
# #### Jak używać funkcji `dir()`?
#
# Oto kilka przykładów wykorzystania funkcji: `dir()` :
#
# ##### **Bez argumentów**: Wywołanie `dir()` bez argumentów zwróci listę nazw zdefiniowanych w bieżącym zakresie.
#
#    ```python
#    x = 10
#    print(dir())
#    ```
#
#    W wyniku zobaczysz listę nazw, w tym m.in. `x`.

# %%
# %%writefile przyklady/przyklad_1_2_2_1.py
x = 10
print(dir())
# Out:
# Overwriting przyklady/przyklad_1_2_2_1.py

# %%
# !python3 przyklady/przyklad_1_2_2_1.py
# Out:
# ['__annotations__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'x']

# %% [markdown]
# Przestrzeń nazw tego notatnika wypełniona jest innymi obiektami niż przestrzeń powyższego przykładu

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_exit_code', '_i', '_i1', '_i2', '_i3', '_i4', '_ih', '_ii', '_iii', '_oh', 'autopep8', 'exit', 'get_ipython', 'json', 'open', 'quit', 'yapf_reformat']

# %% [markdown]
# ##### **Z obiektem jako argumentem**: Możesz przekazać obiekt do funkcji `dir()`, aby zobaczyć jego atrybuty i metody.
#
#    ```python
#    print(dir(str))
#    ```
#
#    W wyniku uzyskasz listę wszystkich metod dostępnych dla typu `str`.

# %%
print(dir(str))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %% [markdown]
# Zadziała to też dla obiekty danej klasy

# %%
dir("napis")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %% [markdown]
# ##### **Dla klasy i instancji**: Możesz użyć `dir()` również dla klasy zdefiniowanej przez Ciebie oraz jej instancji
#
#    ```python
#    class Przyklad:
#        def metoda(self):
#            pass
#
#    instancja = Przyklad()
#
#    print(dir(instancja))
#    ```
#
#    Wynik pokaże atrybuty i metody klasy `Przyklad`, w tym `metoda`.

# %%
class Przyklad:
   def metoda(self):
       pass

instancja = Przyklad()

print(dir(instancja))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'metoda']

# %% [markdown]
# #### Czego można się spodziewać po wynikach?
#
# Lista zwrócona przez `dir()` będzie zawierała zarówno atrybuty wbudowane (często zaczynające się i kończące na podwójnym podkreśleniu, np. `__init__`), jak i zdefiniowane przez użytkownika.
#
# #### Podsumowanie
#
# Funkcja `dir()` w Pythonie jest niezwykle przydatnym narzędziem do eksploracji obiektów. Dzięki niej możemy szybko i łatwo zidentyfikować dostępne metody i atrybuty, co czyni ją nieocenionym pomocnikiem, zwłaszcza w interaktywnym środowisku programowania.

# %% [markdown]
# ### Inne przydatne w nauce funkcje
#
# Przy nauce Pythona wiele funkcji i narzędzi może się okazać niezwykle pomocnych, nie tylko do zrozumienia języka, ale także do diagnozowania problemów i eksploracji dostępnych modułów. Oto kilka z nich:
#
# #### `type()`
#
# Pokazuje typ obiektu. Dzięki temu możesz szybko dowiedzieć się, czy dany obiekt to lista, słownik, napis, czy coś innego.
#
#     ```python
#     x = [1, 2, 3]
#     print(type(x))  # <class 'list'>
#     ```
#
# #### `isinstance()`
#
# Sprawdza, czy obiekt jest instancją określonej klasy lub krotek klas. Użyteczne, jeśli chcesz wiedzieć, czy dany obiekt jest pewnym typem danych bez konieczności bezpośredniego sprawdzania jego typu.
#
#     ```python
#     print(isinstance(x, list))  # True
#     ```
#
# #### `vars()` lub `__dict__`
#
# Dla obiektów pokazuje słownik atrybutów obiektu. Użyteczne głównie dla klas i ich instancji, aby zobaczyć, jakie zmienne instancji zostały ustawione.
#
#     ```python
#     class Przyklad:
#         def __init__(self):
#             self.a = 1
#             self.b = 2
#
#     instancja = Przyklad()
#     print(vars(instancja))  # {'a': 1, 'b': 2}
#     ```
#
# #### `id()`
#
# Zwraca "tożsamość" obiektu, która jest unikalnym identyfikatorem dla tego obiektu podczas trwania jego życia. Użyteczne, gdy chcesz sprawdzić, czy dwie zmienne wskazują na ten sam obiekt w pamięci.
#
# ####  `print()` z `end` i `sep`
#
# Funkcja `print()` ma argumenty, które pozwalają kontrolować, jak coś jest drukowane. Przydatne do formatowania wyjścia.
#
#     ```python
#     print("Hello", "World", sep="-", end="!")  # Hello-World!
#     ```
#
# #### `locals()` i `globals()`
#
# Te funkcje zwracają aktualne zmienne lokalne i globalne. Mogą być przydatne do debugowania i eksploracji zakresu.

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'help()',
#   '# help()\nhelp(str)',
#   '# help()\nhelp(str.upper)',
#   '# help()\nhelp(str.upper)',
#   'str.upper',
#   'str.upper()',
#   'str.upper("ala")',
#   '"ala".upper()',
#   'help("ala".upper)',
#   'help("ala".upper())',
#   'def przykladowa_funkcja():\n    """To jest przykładowa funkcja."""\n    print("Witaj w przykładowej funkcji!")',
#   'help(przykladowa_funkcja)',
#   'przykladowa_funkcja.__name__',
#   'przykladowa_funkcja.__dict__',
#   'przykladowa_funkcja.__annotations__',
#   'przykladowa_funkcja.__name__ = "cos"',
#   'help(przykladowa_funkcja)',
#   'cos',
#   'przykladowa_funkcja()',
#   'przykladowa_funkcja.__name__',
# ...

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'help()',
#   '# help()\nhelp(str)',
#   '# help()\nhelp(str.upper)',
#   '# help()\nhelp(str.upper)',
#   'str.upper',
#   'str.upper()',
#   'str.upper("ala")',
#   '"ala".upper()',
#   'help("ala".upper)',
#   'help("ala".upper())',
#   'def przykladowa_funkcja():\n    """To jest przykładowa funkcja."""\n    print("Witaj w przykładowej funkcji!")',
#   'help(przykladowa_funkcja)',
#   'przykladowa_funkcja.__name__',
#   'przykladowa_funkcja.__dict__',
#   'przykladowa_funkcja.__annotations__',
#   'przykladowa_funkcja.__name__ = "cos"',
#   'help(przykladowa_funkcja)',
#   'cos',
#   'przykladowa_funkcja()',
#   'przykladowa_funkcja.__name__',
# ...

# %%
print( locals() == globals())

def foo():
    a = 1
    print(locals())
    print(globals())

foo()
# Out:
# True
# {'a': 1}
# ...

# %% [markdown]
# #### `getattr()`, `setattr()`, i `hasattr()`
#
# Funkcje te umożliwiają dynamiczne pobieranie, ustawianie lub sprawdzanie atrybutów obiektu. Mogą być przydatne w zaawansowanych przypadkach programowania.
#
# #### `importlib`
#
# Moduł ten umożliwia dynamiczne importowanie innych modułów i ma funkcje takie jak `import_module()`, które pozwalają na importowanie modułów podczas wykonywania programu.
#
# #### `inspect`
#
# Jest to moduł, który dostarcza wiele funkcji do introspekcji i uzyskiwania informacji o żywych obiektach, takich jak moduły, klasy, funkcje i inne. Za pomocą tego modułu można, na przykład, sprawdzić źródło funkcji, jej sygnaturę i wiele innych informacji.
#
# Moduł `inspect` w Pythonie dostarcza wiele funkcji służących do introspekcji i uzyskiwania informacji o obiektach w czasie wykonywania programu. Oto kilka przykładów użycia funkcji z tego modułu:
#
# #####  Sprawdzanie, czy obiekt to funkcja
#
# Za pomocą funkcji `isfunction` można sprawdzić, czy dany obiekt to funkcja:
#
# ```python
# import inspect
#
# def moja_funkcja():
#     pass
#
# print(inspect.isfunction(moja_funkcja))  # True
# ```
#
# ##### Pobieranie źródła funkcji
#
# Jeśli chcesz zobaczyć źródło danej funkcji, możesz użyć `getsource`:
#
# ```python
# print(inspect.getsource(moja_funkcja))
# ```
#
# Wynik:
#
# ```python
# def moja_funkcja():
#     pass
# ```
#
# #####  Pobieranie sygnatury funkcji
#
# Aby zobaczyć sygnaturę funkcji, w tym jej argumenty, wartości domyślne i inne, można użyć `signature`:
#
# ```python
# def funkcja_przyklad(a, b=10, *args, **kwargs):
#     pass
#
# sig = inspect.signature(funkcja_przyklad)
# print(sig)  # (a, b=10, *args, **kwargs)
# ```
#
# ##### Wyszukiwanie funkcji w module
#
# Możesz również użyć `getmembers` do przeszukiwania modułu pod kątem funkcji:
#
# ```python
# import math
#
# functions_in_math = inspect.getmembers(math, inspect.isfunction)
# print(functions_in_math)
# ```
#
# Wyżej podane przykłady pokazują tylko wierzchołek góry lodowej, jeśli chodzi o możliwości modułu `inspect`. Jest to potężne narzędzie do introspekcji w Pythonie i jest niezwykle przydatne podczas debugowania, tworzenia narzędzi lub po prostu chcąc dowiedzieć się więcej o tym, jak działają różne obiekty w Pythonie.

# %% [markdown]
# ### Gdzie szukać pomocy dotyczącej Pythona?
#
# Python, jako jeden z najbardziej popularnych języków programowania na świecie, posiada rozbudowaną społeczność oraz wiele źródeł informacji, które mogą być pomocne podczas nauki i rozwiązywania problemów. Jeżeli napotkasz trudności lub potrzebujesz dodatkowych informacji, oto kilka miejsc, w których warto szukać pomocy:
#
# ####  Dokumentacja Pythona
# Oficjalna [dokumentacja Pythona](https://docs.python.org/3/) to bezcenne źródło wiedzy na temat tego języka. Znajdziesz tam pełny opis biblioteki standardowej, przewodniki oraz tutoriale. Dokumentacja jest dobrze napisana, a często zawiera przykłady kodu.
#
# #### Stack Overflow
# [Stack Overflow](https://stackoverflow.com/) to największe forum programistyczne na świecie. Wielu programistów dzieli się tam swoją wiedzą i pomaga rozwiązywać problemy innych użytkowników. Szanse są duże, że ktoś już napotkał podobny problem jak ty i otrzymał na niego odpowiedź. Pamiętaj jednak, aby zawsze weryfikować rozwiązania znalezione na Stack Overflow – nie wszystkie są optymalne czy bezpieczne.
#
# ####  Rozwiązania LLM: ChatGPT, Bard i inne
# Modele językowe takie jak ChatGPT czy Bard oferują możliwość interakcji i uzyskania odpowiedzi na pytania związane z Pythonem w formie rozmowy. Chociaż są one potężnym narzędziem i potrafią dostarczyć błyskawicznych odpowiedzi, istnieją pewne zagrożenia:
#
# - **Niepełna dokładność**: Modele bazują na danych treningowych i nie zawsze dostarczają 100% dokładnych odpowiedzi.
# - **Bezpieczeństwo**: W oparciu o dostarczone odpowiedzi nie można dokonywać krytycznych decyzji biznesowych czy bezpieczeństwa. Zawsze warto weryfikować informacje.
# - **Brak kontekstu**: Modele te działają na podstawie podanych im informacji, co może prowadzić do błędnych interpretacji.
#
# #### Społeczność
# Grupy na platformach takich jak Reddit (np. r/learnpython), fora takie jak Python Forum czy lokalne grupy i organizacje związane z Pythonem mogą być niesamowicie pomocne. Często organizują one spotkania, warsztaty i konferencje, które są świetną okazją do nauki i nawiązywania kontaktów.
#
# #### 5. Kursy online
# Istnieje wiele kursów online (np. na platformach Coursera, Udemy) skupiających się na nauce Pythona. Często zawierają one fora dyskusyjne, gdzie uczestnicy mogą zadawać pytania i otrzymywać odpowiedzi od instruktorów oraz innych uczestników.
#
# #### Podsumowanie
# Choć dostępnych jest wiele źródeł informacji o Pythonie, kluczem jest umiejętność krytycznej oceny i weryfikacji zdobytej wiedzy. Niezależnie od tego, czy korzystasz z oficjalnej dokumentacji, forów, modeli językowych czy innych źródeł, zawsze pamiętaj o potencjalnych ryzykach i ograniczeniach każdego z nich.

# %% [markdown]
# %%writefile cwiczenia/cwiczenie_1_2_5.md
# ### 📝 Ćwiczenie z użycia funkcji `help` i `dir` w Pythonie
#
# [Cwiczenie 1_2_5](cwiczenia/cwiczenie_1_2_5.md)
#
#
# **Cel:** Zrozumienie, jak korzystać z funkcji `help` i `dir` do eksploracji modułów, klas i funkcji w Pythonie.
#
# **Kroki:**
#
# 1. **Eksploracja modułu standardowego**
#     - Zaimportuj moduł `os`.
#     - Użyj `dir(os)` do wyświetlenia listy dostępnych funkcji i atrybutów w module `os`.
#     - Wybierz 3 funkcje z listy (na przykład: `os.getcwd`, `os.listdir`, `os.mkdir`).
#     - Użyj `help(os.FUNKCJA)` dla każdej z trzech wybranych funkcji, aby zrozumieć, jak działają i jakie przyjmują argumenty.
#
# 2. **Eksploracja wbudowanej klasy**
#     - Utwórz listę (np. `moja_lista = [1, 2, 3, 4]`).
#     - Użyj `dir(moja_lista)` do wyświetlenia listy dostępnych metod dla obiektu typu lista.
#     - Wybierz 3 metody z listy (na przykład: `append`, `pop`, `index`).
#     - Użyj `help(moja_lista.METODA)` dla każdej z trzech wybranych metod, aby zrozumieć, jak działają.
#
# 3. **Stworzenie własnej klasy i eksploracja jej metod**
#     - Utwórz prostą klasę:
#
#     ```python
#     class Samochod:
#         def __init__(self, marka, model):
#             self.marka = marka
#             self.model = model
#
#         def pokaz_info(self):
#             return f"Samochód {self.marka} model {self.model}"
#     ```
#
#     - Użyj `dir(Samochod)` do wyświetlenia listy metod dla klasy `Samochod`.
#     - Spróbuj użyć `help(Samochod.pokaz_info)`, aby zrozumieć, jak działa metoda `pokaz_info`.
#
# **Zadanie dodatkowe:** Wypróbuj funkcję `dir` bez żadnych argumentów w interaktywnym interpreterze Pythona i zastanów się, co ona zwraca. Jakie zmienne i funkcje są dostępne w bieżącym zakresie?
#
# **Podsumowanie:** Po zakończeniu tego ćwiczenia powinieneś być w stanie skutecznie korzystać z funkcji `help` i `dir` do eksploracji i zrozumienia różnych aspektów modułów, klas i funkcji w Pythonie.

# %% [markdown]
# ## Słowa kluczowe Pythona - Keywords
#
# Słowa kluczowe w Pythonie to zarezerwowane słowa, które mają specjalne znaczenie dla interpretera. Nie można ich używać jako identyfikatorów, np. nazw zmiennych czy funkcji. Oto krótka charakterystyka najważniejszych słów kluczowych:
#
# ### Wartości - singletony
# - **True**: wartość logiczna oznaczająca prawdę.
# - **False**: wartość logiczna oznaczająca fałsz.
# - **None**: specjalna wartość oznaczająca brak wartości.
#
# ### Operatory i wyrażenia warunkowe
# - **and**: operator logiczny "i".
# - **or**: operator logiczny "lub".
# - **not**: operator logiczny "nie".
# - **is**: porównuje tożsamość obiektów.
# - **in**: sprawdza przynależność elementu do sekwencji.
#
# - **if**: wprowadza blok instrukcji warunkowych.
# - **elif**: wprowadza dodatkowy warunek w bloku `if`.
# - **else**: wprowadza blok instrukcji, który zostanie wykonany, jeśli poprzednie warunki były fałszywe.
#
# ### Obsługa asynchroniczności
# - **async**: deklaruje asynchroniczną funkcję lub kontekst.
# - **await**: czeka na wynik asynchronicznej operacji.
#
# ### Nowe typy i funkcje
# - **def**: definiuje nową funkcję.
# - **class**: definiuje nową klasę.
# - **return**: zwraca wartość z funkcji.
# - **yield**: zwraca wartość z funkcji generatora.
# - **pass**: pusty statement; nic nie robi.
#
# ### Walidacje
# - **assert**: używane do debugowania; rzuca wyjątek, jeśli wyrażenie jest fałszywe.
#
# ### Pętle
# - **for**: wprowadza pętlę for.
# - **while**: wprowadza pętlę while.
# - **else**: w kontekście pętli, wykonuje blok kodu, gdy pętla zakończy się normalnie (bez `break`).
#
# #### Przerwania w pętlach
# - **break**: przerywa pętlę.
# - **continue**: przechodzi do następnej iteracji pętli.
#
# ### Wyjątki
# - **raise**: rzuca wyjątek.
# - **try**: definiuje blok instrukcji do "próby".
# - **except**: definiuje blok instrukcji do obsługi wyjątków.
# - **finally**: definiuje blok instrukcji, który zostanie wykonany niezależnie od tego, czy wystąpił wyjątek.
#
# ### Operowanie na przestrzeniach nazw
# - **global**: deklaruje zmienną jako globalną.
# - **nonlocal**: odnosi się do zmiennej w najbliższym otaczającym zakresie, który nie jest globalny.
# - **del**: usuwa referencję do obiektu.
#
# ### Importowanie
# - **import**: importuje moduł.
# - **from**: importuje określone atrybuty z modułu.
# - **as**: definiuje alias dla importowanego modułu lub atrybutu.
#
# ### Managery kontekstu
# - **with**: wprowadza blok kodu zarządzany przez menedżera kontekstu.
# - **as**: w kontekście `with`, przypisuje obiekt do zmiennej.
#
# Te słowa kluczowe stanowią podstawę składni Pythona i są niezbędne do pisania skutecznych programów w tym języku. Używanie ich zgodnie z przeznaczeniem pozwala na tworzenie czytelnego i efektywnego kodu.

# %% [markdown]
# %%writefile cwiczenia/cwiczenie_1_3_11.md
#
# ### 📝 Ćwiczenie: Rozróżnianie między słowami kluczowymi a funkcjami wbudowanymi
#
# [Cwiczenie 1_3_11](cwiczenia/cwiczenie_1_3_11.md)
#
# #### Cel:
# Zrozumienie podstawowej różnicy między słowami kluczowymi a funkcjami wbudowanymi w Pythonie oraz poznawanie granic i możliwości w redefiniowaniu funkcji wbudowanych.
#
# #### Instrukcje:
#
# 1. **Słowo kluczowe vs. funkcja**: Czy możesz zdefiniować własną funkcję o nazwie `if`? Dlaczego?
#
# 2. **Redefiniowanie funkcji wbudowanych**: Czy możesz zdefiniować własną funkcję o nazwie `print`? Jakie mogą być tego konsekwencje?
#
# 3. **Składnia funkcji**: Spróbuj użyć `print` bez nawiasów. Co się dzieje? Dlaczego?

# %% [markdown]
# #### Odpowiedzi:
#
# 1. **Słowo kluczowe vs. funkcja**: Nie możesz zdefiniować funkcji o nazwie `if`, ponieważ `if` jest słowem kluczowym w Pythonie. Słowa kluczowe są zarezerwowane i nie mogą być używane jako identyfikatory.
#
# 2. **Redefiniowanie funkcji wbudowanych**: Tak, możesz zdefiniować własną funkcję o nazwie `print`, ale to nadpisze wbudowaną funkcję `print`. Oznacza to, że standardowe zachowanie `print` zostanie zastąpione przez twoją funkcję, co może prowadzić do nieoczekiwanych błędów i problemów w kodzie.
#
# 3. **Składnia funkcji**: Jeśli użyjesz `print` bez nawiasów w Pythonie 3, otrzymasz błąd, ponieważ nawiasy są wymagane dla wywołań funkcji. W Pythonie 2 `print` był instrukcją, a nie funkcją, więc nawiasy nie były wymagane. Jeśli próbujesz tego w środowisku Pythona 2, zobaczysz wynik bez błędów.

# %% [markdown]
# ## Operatory w Pythonie
#
# Python, jak większość języków programowania, udostępnia różnorodne operatory, które pozwalają na przeprowadzanie operacji na zmiennych i wartościach. mozemy rozróżnić operatory dwuargumentowe - gdy z lewej i prawej strony operatora znajdują się obiekty oraz operatory jednoargumentowe - operator poprzedza obiekt.
#
# Operatory można podzielić na kilka kategorii w zależności od ich przeznaczenia.
#
#
# ### operatory arytmetyczne
#
#
# | operator | nazwa               | przykład      | wynik |
# | -------- | ------------------- | --------      | ----- |
# | +        | dodawanie           | 5 + 3         | 8     |
# | -        | odejmowanie         | 5 - 3         | 2     |
# | /        | dzielenie           | 5 / 2         | 2.5   |
# | //       | dzielenie całkowite | 5 // 2        | 2     |
# | *        | mnożenie            | 5 * 3         | 15    |
# | **       | potęgowanie         | 5 ** 2        | 25    |
# | %        | dzielenie modulo    | 5 % 2         | 1     |
# | @        | mnożenie macierzy   | [[2]] @ [[3]] | [[6]] |
#
# Uwaga: Operator `@` do mnożenia macierzy został wprowadzony w Pythonie 3.5 i jest często używany z bibliotekami takimi jak NumPy. W samym Pythonie nie ma jeszcze wbudowanych typów, które wykorzystują ten operator.
#
# https://peps.python.org/pep-0465/

# %% [markdown]
# ### operatory algebry zbiorów
#
# Działają na obiektach typu `set`
#
# | operator | przykład             | wynik     |
# | -------- | -------------------- | --------- |
# | &        | {1, 2} & {2, 3}      | {2}       |
# | &#124;   | {1, 2} &#124; {2, 3} | {1, 2, 3} |
# | ^        | {1, 2} ^ {2, 3}      | {1, 3}    |
# | -        | {1, 2} - {2, 3}      | {1}       |

# %% [markdown]
# ### operatory przypisania:
#
# | operator | przykład    | równoważność   |
# | :------: | ----------- | -------------- |
# | =        | x = 5       | x = 5          |
# | +=       | x += 3      | x = x + 3      |
# | -=       | x -= 3      | x = x - 3      |
# | *=       | x *= 3      | x = x * 3      |
# | /=       | x /= 3      | x = x / 3      |
# | %=       | x %= 3      | x = x % 3      |
# | //=      | x //= 3     | x = x // 3     |
# | **=      | x **= 3     | x = x ** 3     |
# | &=       | x &= 3      | x = x & 3      |
# | &#124;=  | x &#124;= 3 | x = x &#124; 3 |
# | ^=       | x ^= 3      | x = x ^ 3      |
# | >>=      | x >>= 3     | x = x >> 3     |
# | <<=      | x <<= 3     | x = x << 3     |
#
#
#
#
# ### operatory porównania:
#
# | operator | nazwa                    | przykład            |
# | :------: | ------------------------ | ------------------- |
# | ==       | Equal                    | x == y              |
# | !=       | Not equal                | x != y              |
# | >        | Greater than             | x > y               |
# | <        | Less than                | x < y               |
# | >=       | Greater than or equal to | x >= y              |
# | <=       | Less than or equal to    | x <= y              |
# | :=       | Walrus operator          | if x := 2 < 3: pass |
#
#
# ### operatory logiczne
#
# | operator | nazwa                                         | przykład              |
# | :------: | --------------------------------------------- | --------------------- |
# | and      | Returns True if both statements are true      | x < 5 and  x < 10     |
# | or       | Returns True if one of the statements is true | x < 5 or x < 4        |
# | not      | Reverse the result                            | not(x < 5 and x < 10) |
#
# ### operatory identyczności, tożsamości
#
# | operator | nazwa                                                  | przykład   |
# | :------: | ------------------------------------------------------ | ---------- |
# | is       | Returns True if both variables are the same object     | x is y     |
# | is not   | Returns True if both variables are not the same object | x is not y |
#
#
# ### operatory przynależnośći
#
# | operator | nazwa                                                                            | przykład   |
# | :------: | -------------------------------------------------------------------------------- | ---------- |
# | in       | Returns True if a sequence with the specified value is present in the object     | x in y     |
# | not in   | Returns True if a sequence with the specified value is not present in the object | x not in y |
#
#
# ### operatory bitowe
#
# | operator | nazwa                | opis | przykład               | wynik      |
# | :------: | -------------------- | ---- | :--------------------: | ---------- |
# | &        | AND                  |      | bin(0b10  & 0b01)      | 0b0        |
# | &#124;   | OR                   |      | bin(0b10  &#124; 0b01) | 0b11       |
# | ^        | XOR                  |      | bin(0b10 ^ 0b01)       | 0b11       |
# |          |                      |      | bin(0b10 ^ 0b10)       | 0b0        |
# | ~        | NOT                  |      | ~0b1                   | -2         |
# |          |                      |      | bin(~0b1)              | -0b10      |
# | <<       | Zero fill left shift |      | bin(0b00111100 << 2)   | 0b11110000 |
# | >>       | Signed right shift   |      | bin(0b00111100 >> 2)   | 0b1111     |
#
# Inne przykłady:

# %%
print('0b{:04b}'.format(0b1100 & 0b1010),
'0b{:04b}'.format(0b1100 | 0b1010),
'0b{:04b}'.format(0b1100 ^ 0b1010),
'0b{:04b}'.format(0b1100 >> 2),
'0b{:04b}'.format(0b0011 << 2), sep="\n")
# Out:
# 0b1000
# 0b1110
# 0b0110
# 0b0011
# 0b1100

# %%
3 << 2
# Out:
# 12

# %% [markdown]
# #### Działanie operatora przesunięcia bitowego
#
# Aby zrozumieć, dlaczego `3 << 2` daje wynik `12`, musisz najpierw zrozumieć, jak działa operator przesunięcia bitowego w lewo (`<<`).
#
# Operator `<<` przesuwa bity liczby w lewo o określoną liczbę pozycji. Wszystkie wolne miejsca po przesunięciu są wypełniane zerami.
#
# Spróbujmy zastosować ten operator na liczbie `3`:
#
# Reprezentacja binarna liczby `3` to: `11`
#
# Przesuwając bity tej liczby o `2` pozycje w lewo, otrzymujemy: `1100`
#
# Teraz przekształćmy `1100` z postaci binarnej na dziesiętną:
# - 2^0 * 0 = 0
# - 2^1 * 0 = 0
# - 2^2 * 1 = 4
# - 2^3 * 1 = 8
#
# Sumując te wartości, dostajemy `8 + 4 = 12`.
#
# Dlatego `3 << 2` daje wynik `12`.
#
# Analogicznie - operator `>>` przesuwa bity liczby w prawo o określoną liczbę pozycji.
#
# Spróbujmy zastosować ten operator w ten sposób `16 >> 3`:
#
# Reprezentacja binarna liczby `16` to: `10000`
#
# Przesuwając bity tej liczby o `3` pozycje w prawo, otrzymujemy: `10`
#
# Teraz przekształćmy `10` z postaci binarnej na dziesiętną:
# - 2^0 * 0 = 0
# - 2^1 * 1 = 2
#
# Dodając te wartości, dostajemy `2`.
#
# Dlatego `16 >> 3` daje wynik `2`.

# %% [markdown]
# ### Operator "Walrus" (`:=`) w Pythonie
#
# Operator "Walrus", czyli `:=`, został wprowadzony w Pythonie 3.8 jako nowa funkcja języka. Jego głównym celem jest przypisanie wartości do zmiennej w trakcie ewaluacji wyrażenia.
#
#
# Zamiast pisać:
# ```python
# value = some_function()
# if value:
#     do_something(value)
# ```
#
# Możesz skrócić to do:
# ```python
# if (value := some_function()):
#     do_something(value)
# ```
#
# * Zalety:
#
# Operator `:=` pozwala na zwiększenie czytelności kodu poprzez eliminację potrzeby wielokrotnego wywoływania tej samej funkcji lub sprawdzania tej samej wartości w różnych miejscach. Jest szczególnie przydatny w przypadku pętli `while`, list comprehensions i warunków `if`.
#
# * Ostrzeżenie:
#
# Chociaż operator "Walrus" może poprawić czytelność kodu w niektórych przypadkach, może też wprowadzić pewne niejednoznaczności, jeśli jest używany nadmiernie lub w niewłaściwy sposób. Ważne jest, aby korzystać z niego roztropnie i upewnić się, że kod pozostaje czytelny dla innych programistów.
#
# W skrócie, operator `:=` jest potężnym narzędziem w arsenale programisty Pythona, ale tak jak każde narzędzie, wymaga stosowania z rozwagą.

# %% [markdown]
# %%writefile cwiczenia/cwiczenie_1_4_9_1.md
#
# #### 📝 Ćwiczenie: operator `:=`
#
# [Cwiczenie 1_4_9_1](cwiczenia/cwiczenie_1_4_9_1.md)
#
#
# Masz daną listę liczb i chcesz znaleźć pierwszą liczbę większą od 10, a jednocześnie chcesz wiedzieć, na którym miejscu w liście ta liczba się znajduje.
#
# 1. Utwórz listę liczb:
#    ```python
#    liczby = [7, 3, 12, 5, 14, 8, 9]
#    ```
#
# 2. Używając pętli `while` i operatora walrusa, znajdź pierwszą liczbę większą od 10 oraz jej indeks:
#
#    ```python
#    indeks = 0
#
#    # tu twoja implementacja
#
#    if indeks < len(liczby):
#        print(f"Pierwsza liczba większa od 10 to {liczba}, znajdująca się na pozycji {indeks}.")
#    else:
#        print("Nie znaleziono liczby większej od 10 w liście.")
#    ```
#
# Sprawdź rozwiązanie dla różnych list.

# %%
liczby = [7, 3, 12, 5, 14, 8, 9]
liczby = [1, 2, 1, 2, 1, 2]
indeks = 0

# tu twoja implementacja
while indeks < len(liczby) and (liczba := liczby[indeks]) <= 10:
    indeks += 1

if indeks < len(liczby):
   print(f"Pierwsza liczba większa od 10 to {liczba}, znajdująca się na pozycji {indeks}.")
else:
   print("Nie znaleziono liczby większej od 10 w liście.")
# Out:
# Nie znaleziono liczby większej od 10 w liście.

# %% [markdown]
# ##### rozwiązanie:

# %%
indeks = 0
liczby = [7, 3, 12, 5, 14, 8, 9]

while (indeks < len(liczby)) and (liczba := liczby[indeks]) <= 10:
    indeks += 1

if indeks < len(liczby):
    print(f"Pierwsza liczba większa od 10 to {liczba}, znajdująca się na pozycji {indeks}.")
else:
    print("Nie znaleziono liczby większej od 10 w liście.")
# Out:
# Pierwsza liczba większa od 10 to 12, znajdująca się na pozycji 2.

# %% [markdown]
# ##### Wnioski:
#
# Operator walrusa pozwala na bardziej zwięzłe i czytelne pisanie kodu w pewnych sytuacjach. Dzięki niemu możemy jednocześnie przypisać wartość do zmiennej i użyć tej wartości w wyrażeniu, co może znacznie upraszczać niektóre konstrukcje, takie jak pętle czy instrukcje warunkowe.

# %% [markdown]
# ### Kolejność wykonywania operatorów
#
# |                    | Operator                         | Description                                      |
# | :----------------: | -------------------------------- | ------------------------------------------------ |
# | lowest precedence  | or                               | Boolean OR                                       |
# |                    | and                              | Boolean AND                                      |
# |                    | not                              | Boolean NOT                                      |
# |                    | ==, !=, <, <=, >, >=, is, is not | comparisons, identity                            |
# |                    | &#124;                           | bitwise OR                                       |
# |                    | ^                                | bitwise XOR                                      |
# |                    | &                                | bitwise AND                                      |
# |                    | <<, >>                           | bit shifts                                       |
# |                    | +, -                             | addition, subtraction                            |
# |                    | *, /, //, %                      | multiplication, division, floor division, modulo |
# |                    | +x, -x, ~x                       | unary positive, unary negation, bitwise negation |
# | highest precedence | **                               | exponentiation                                   |

# %% [markdown]
# %%writefile cwiczenia/cwiczenie_1_4_10_1.md
#
# #### 📝 Ćwiczenie: Kolejność wykonywania operatorów
#
# [Cwiczenie 1_4_10_1](cwiczenia/cwiczenie_1_4_10_1.md)
#
#
# Rozważ poniższe wyrażenie:
#
# ```python
# wynik = 2 + 3 * 5 - 8 / 4 ** 2 % 3
# ```
#
# Zanim uruchomisz ten kod, postaraj się przewidzieć wynik wyrażenia, pamiętając o kolejności wykonywania operatorów w Pythonie.

# %% [markdown]
# ##### Rozwiązanie
#
# **Kroki**:
#
# 1. Określ kolejność wykonywania operatorów w wyrażeniu.
# 2. Oblicz wyrażenie krok po kroku, zaczynając od operatorów o najwyższym priorytecie.
# 3. Porównaj swój wynik z tym uzyskanym po uruchomieniu kodu.
#
# **Odpowiedź**:
#
# Kolejność wykonywania operatorów w Pythonie jest następująca (od najwyższego do najniższego priorytetu):
#
# 1. `**`
# 2. `*`, `/`, `%`, `//`
# 3. `+`, `-`
#
# Korzystając z tej kolejności:
#
# 1. Oblicz `4 ** 2` = 16
# 2. Oblicz `8 / 16` = 0.5
# 3. Oblicz `0.5 % 3` = 0.5
# 4. Oblicz `3 * 5` = 15
# 5. Oblicz `2 + 15` = 17
# 6. Oblicz `17 - 0.5` = 16.5
#
# Więc `wynik` to `16.5`.
