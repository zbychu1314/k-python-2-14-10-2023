# %% [markdown]
# lambda niekiedy moze byc szybsza od zwykles funkcji
# ![image.png](attachment:326ce9ea-b1fb-4796-9a96-da78aa129eab.png)

# %% [markdown]
# from functools import wraps
# ![image.png](attachment:56f3f889-1426-4e2c-b174-80f1c7e308dc.png)

# %% [markdown]
# wraps przepisze ze nas doc name etc
# ![image.png](attachment:3c0b17f1-ab5a-43f7-8e29-e0dc66b8467d.png)

# %% [markdown]
# powyzej udekorowana z argumentami

# %% [markdown]
# ![image.png](attachment:72e05444-f456-428c-ae28-4b1f374bd780.png)

# %% [markdown]
# teraz bedzi dzialac poprawnie niezaleznie od argumentow

# %% [markdown]
# ![image.png](attachment:73d9e587-0e81-437f-9d8c-bf8394e78c4b.png)

# %% [markdown]
# ![image.png](attachment:18937f88-9aa2-4a11-bbab-afa392d56126.png)

# %% [markdown]
# jestli zwroci typ to jest klasa

# %% [markdown]
# operator property

# %% [markdown]
# ![image.png](attachment:bd53626f-cbf7-4929-937e-9adb242d760d.png)

# %% [markdown]
# bez setterow
# bedzie wiecej metod, bez property bedzie niespojnosc wiek to cecha a nie funkcja wiec bardziej logiczne jest zastastowanie dekoratora property

# %%
getter, deleter
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 getter, deleter
#
# NameError: name 'getter' is not defined

# %% [markdown]
# deskryptory funkcjnalnie podobne do property
# towrzymy klase ktora bedzie miec get set
# ![image.png](attachment:382f9146-697b-4f30-950d-08d85344fd4b.png)

# %% [markdown]
# generator to jest iterator,

# %% [markdown]
# ![image.png](attachment:d264b1c8-8e6b-465c-9a6f-7a1ce5505caa.png)

# %% [markdown]
# context manager musza miec metody enter i exit

# %% [markdown]
# jak wchodzimy do contex manager to wykonuje sie enter a jak wychodzimy wykonuje sie exit
# ![image.png](attachment:8fca3f49-bff5-4ecd-8994-f05c4eb4ed5e.png)

# %% [markdown]
# powyzej przyklad context managera, widac ze plik sie zamyka po wyjsciu
# moze sie przydac w sytacji gdy korzystamy z polacznia z baza danych

# %% [markdown]
# klasy abstrakcyjne
# jesli dziedziczymy, wewnatrz klasy mozemy zasygnalizowac ze musi posiadac jakas metode, w kolejnej klasie juz nie abstrakcyjnej musi byc konkretna implementacja metody zagraj
#
# ![image.png](attachment:ce73195e-74ff-4b21-b1ed-6ac09ef658cf.png)

# %% [markdown]
# @abstractproperty umozliwia wymuszenie w klasach dziedziczonych ustawianie danego atrybutu
# ![image.png](attachment:1c6783ed-af2c-42ae-8b98-38330ce70359.png)

# %% [markdown]
# dekorator staticmethod
#
# ![image.png](attachment:322e2999-72ba-463c-a254-54c8e91199b2.png)

# %% [markdown]
# static metod kiedy definujemy klase ale metoda nie do konca ma zwiazek z instancja klasy

# %%
adapter to pewnie wzorzec projektowy
